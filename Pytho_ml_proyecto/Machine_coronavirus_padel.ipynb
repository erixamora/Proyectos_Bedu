# %%
import pandas as pd

# %%
df = pd.read_csv('datos_acetylcholinesterase_pIC50.csv')
df
# Out:
#      Unnamed: 0 molecule_chembl_id  \
# 0             0       CHEMBL187579
# 1             1       CHEMBL188487
# 2             2       CHEMBL185698
# 3             3       CHEMBL426082
# 4             4       CHEMBL187717
# ..          ...                ...
# 128         128      CHEMBL2146517
# 129         129       CHEMBL187460
# 130         130       CHEMBL363535
# 131         131       CHEMBL227075
# 132         132        CHEMBL45830
#
#                                       canonical_smiles bioactivity_class  \
# 0               Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21        intermedio
# 1               O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21        intermedio
# 2              O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21          inactivo
# 3                  O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21          inactivo
# 4      O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]        intermedio
# ..                                                 ...               ...
# ...

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df_selection = df[selection]
df_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
df2_X= pd.read_csv('resultados_padel.csv')
df2_X
# Out:
#               Name  nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  \
# 0     CHEMBL187579      0 -0.1274  0.016231  36.7824  39.440723          11
# 1     CHEMBL188487      0  1.7571  3.087400  37.9340  42.525344          12
# 2     CHEMBL185698      0  0.1861  0.034633  42.7942  47.579516          12
# 3     CHEMBL426082      0 -0.2964  0.087853  25.2932  42.858723          15
# 4     CHEMBL187717      0  0.3637  0.132278  29.1832  44.895930          15
# ..             ...    ...     ...       ...      ...        ...         ...
# 128  CHEMBL2146517      0  0.0805  0.006480  50.5666  51.212274          11
# 129   CHEMBL187460      0  0.0397  0.001576  60.2519  49.181860           6
# 130   CHEMBL363535      0  0.6023  0.362765  23.3153  42.087516          15
# 131   CHEMBL227075      0 -0.0693  0.004802  39.4869  43.421102          10
# 132    CHEMBL45830      0  1.0685  1.141692  60.3254  49.713446           6
#
# ...

# %%
df2_X = df2.drop(columns=['Name'])
df2_X
# Out:
#      nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        0 -0.1274  0.016231  36.7824  39.440723          11         11
# 1        0  1.7571  3.087400  37.9340  42.525344          12         12
# 2        0  0.1861  0.034633  42.7942  47.579516          12         12
# 3        0 -0.2964  0.087853  25.2932  42.858723          15         16
# 4        0  0.3637  0.132278  29.1832  44.895930          15         16
# ..     ...     ...       ...      ...        ...         ...        ...
# 128      0  0.0805  0.006480  50.5666  51.212274          11         12
# 129      0  0.0397  0.001576  60.2519  49.181860           6          6
# 130      0  0.6023  0.362765  23.3153  42.087516          15         17
# 131      0 -0.0693  0.004802  39.4869  43.421102          10         11
# 132      0  1.0685  1.141692  60.3254  49.713446           6          6
#
#      nAtom  nHeavyAtom  nH  ...  SubFPC298  SubFPC299  SubFPC300  SubFPC301  \
# ...

# %%
df2_Y = df['pIC50']
df2_Y
# Out:
# 0      5.142668
# 1      5.026872
# 2      4.869666
# 3      4.882397
# 4      5.698970
#          ...
# 128    4.974694
# 129    4.995679
# 130    4.939302
# 131    4.970616
# 132    4.102923
# Name: pIC50, Length: 133, dtype: float64

# %%
dataset = pd.concat([df2_X,df2_Y], axis=1)
dataset
# Out:
#      nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        0 -0.1274  0.016231  36.7824  39.440723          11         11
# 1        0  1.7571  3.087400  37.9340  42.525344          12         12
# 2        0  0.1861  0.034633  42.7942  47.579516          12         12
# 3        0 -0.2964  0.087853  25.2932  42.858723          15         16
# 4        0  0.3637  0.132278  29.1832  44.895930          15         16
# ..     ...     ...       ...      ...        ...         ...        ...
# 128      0  0.0805  0.006480  50.5666  51.212274          11         12
# 129      0  0.0397  0.001576  60.2519  49.181860           6          6
# 130      0  0.6023  0.362765  23.3153  42.087516          15         17
# 131      0 -0.0693  0.004802  39.4869  43.421102          10         11
# 132      0  1.0685  1.141692  60.3254  49.713446           6          6
#
#      nAtom  nHeavyAtom  nH  ...  SubFPC299  SubFPC300  SubFPC301  SubFPC302  \
# ...

# %%
dataset.to_csv('datos_pIC50_pubchem_.csv', index=False)
