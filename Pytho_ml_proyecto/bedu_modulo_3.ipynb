# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df[["age","DEATH_EVENT"]]
# Out:
#       age  DEATH_EVENT
# 0    75.0            1
# 1    55.0            1
# 2    65.0            1
# 3    50.0            1
# 4    65.0            1
# ..    ...          ...
# 294  62.0            0
# 295  55.0            0
# 296  45.0            0
# 297  45.0            0
# 298  50.0            0
#
# [299 rows x 2 columns]

# %%
df.sort_values(['serum_creatinine'],ascending= False )
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 9    80.0        1                       123         0                 35
# 217  54.0        1                       427         0                 70
# 52   60.0        0                      3964         1                 62
# 131  60.0        1                      1082         1                 45
# 28   58.0        1                        60         0                 38
# ..    ...      ...                       ...       ...                ...
# 186  50.0        0                       582         0                 50
# 47   60.0        0                       582         1                 38
# 57   60.0        1                       607         0                 40
# 78   75.0        1                       203         1                 38
# 250  50.0        0                      2522         0                 30
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
fallecidos_con_cpk_alta = df.loc[(df["creatinine_phosphokinase"] >= 120) & (df["DEATH_EVENT"] == 1)]

fallecidos_con_cpk_alta
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 4    65.0        1                       160         1                 20
# 6    75.0        1                       246         0                 15
# ..    ...      ...                       ...       ...                ...
# 220  73.0        0                       582         0                 20
# 230  60.0        0                       166         0                 30
# 246  55.0        0                      2017         0                 25
# 262  65.0        1                       258         1                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.groupby(['anaemia']).mean().sort_values('creatinine_phosphokinase', ascending= False)
# Out:
#                age  creatinine_phosphokinase  diabetes  ejection_fraction  \
# anaemia
# 0        59.923529                742.788235  0.423529          37.758824
# 1        62.033597                369.736434  0.410853          38.511628
#
#          high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# anaemia
# 0                   0.335294  267082.215647          1.346941    136.464706
# 1                   0.372093  258450.186744          1.455736    136.837209
#
#               sex   smoking        time  DEATH_EVENT
# anaemia
# 0        0.688235  0.364706  139.805882     0.294118
# 1        0.596899  0.263566  117.682171     0.356589

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...
